# %%
# Import Dependencies
import pandas as pd

# %%
# Obtained Deaths by States and Year that were induced or caused by drug/alcohol from CDC website: https://wonder.cdc.gov/controller/datarequest/D76
df = pd.read_csv('DrugOverdoseMortality_byState.tsv', delimiter='\t')

# %%
#Display dataframe
df
# Out:
#                                                   Notes    State  State Code  \
# 0                                                   NaN  Alabama         1.0
# 1                                                   NaN  Alabama         1.0
# 2                                                   NaN  Alabama         1.0
# 3                                                   NaN  Alabama         1.0
# 4                                                   NaN  Alabama         1.0
# 5                                                   NaN  Alabama         1.0
# 6                                                   NaN  Alabama         1.0
# 7                                                   NaN  Alabama         1.0
# 8                                                   NaN  Alabama         1.0
# 9                                                   NaN  Alabama         1.0
# 10                                                  NaN  Alabama         1.0
# ...

# %%
# Drop rows where "State" = NaN and display dataframe
df = df[df['State'].notnull()]
df
# Out:
#      Notes    State  State Code    Year  Year Code  \
# 0      NaN  Alabama         1.0  1999.0     1999.0
# 1      NaN  Alabama         1.0  1999.0     1999.0
# 2      NaN  Alabama         1.0  1999.0     1999.0
# 3      NaN  Alabama         1.0  1999.0     1999.0
# 4      NaN  Alabama         1.0  1999.0     1999.0
# 5      NaN  Alabama         1.0  1999.0     1999.0
# 6      NaN  Alabama         1.0  2000.0     2000.0
# 7      NaN  Alabama         1.0  2000.0     2000.0
# 8      NaN  Alabama         1.0  2000.0     2000.0
# 9      NaN  Alabama         1.0  2000.0     2000.0
# 10     NaN  Alabama         1.0  2000.0     2000.0
# 11     NaN  Alabama         1.0  2000.0     2000.0
# 12     NaN  Alabama         1.0  2001.0     2001.0
# 13     NaN  Alabama         1.0  2001.0     2001.0
# 14     NaN  Alabama         1.0  2001.0     2001.0
# 15     NaN  Alabama         1.0  2001.0     2001.0
# 16     NaN  Alabama         1.0  2001.0     2001.0
# ...

# %%
# List column names 
list(df.columns)
# Out:
# ['Notes',
#  'State',
#  'State Code',
#  'Year',
#  'Year Code',
#  'Drug/Alcohol Induced',
#  'Drug/Alcohol Induced Code',
#  'Drug/Alcohol Induced Cause',
#  'Drug/Alcohol Induced Cause Code',
#  'Deaths',
#  'Population',
#  'Crude Rate',
#  'Crude Rate Standard Error']

# %%
# Drop unnecessary columns
df.drop(['Notes', 'State Code', 'Year Code', 'Drug/Alcohol Induced Code', 'Drug/Alcohol Induced Cause Code', 'Population', 'Crude Rate Standard Error'], axis=1, inplace=True)
df
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#         State    Year                       Drug/Alcohol Induced  \
# 0     Alabama  1999.0                        Drug-induced causes
# 1     Alabama  1999.0                        Drug-induced causes
# 2     Alabama  1999.0                        Drug-induced causes
# 3     Alabama  1999.0                        Drug-induced causes
# 4     Alabama  1999.0                     Alcohol-induced causes
# 5     Alabama  1999.0  All other non-drug and non-alcohol causes
# 6     Alabama  2000.0                        Drug-induced causes
# 7     Alabama  2000.0                        Drug-induced causes
# 8     Alabama  2000.0                        Drug-induced causes
# ...

# %%
# Display data types
df.dtypes
# Out:
# State                          object
# Year                          float64
# Drug/Alcohol Induced           object
# Drug/Alcohol Induced Cause     object
# Deaths                        float64
# Crude Rate                     object
# dtype: object

# %%
# Use map function to round 'Year' and 'Death' to drop decimal and display dataframe
df['Year'] = df.Year.map(round)
df['Deaths'] = df.Deaths.map(round)
df
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         State  Year                       Drug/Alcohol Induced  \
# 0     Alabama  1999                        Drug-induced causes
# 1     Alabama  1999                        Drug-induced causes
# ...

# %%
# Create condition for 'All other non-drug and non-alcohol causes'
NonDrug_deaths = df[df['Drug/Alcohol Induced'] == 'All other non-drug and non-alcohol causes'].index

# Delete rows that meet condition from dataFrame to only keep drug/alcohol related deaths
df.drop(NonDrug_deaths, inplace=True)

# Create condition for Crude Rate 'Unreliable'
CrudeRate = df[df['Crude Rate'] == 'Unreliable'].index

# Delete rows that meet condition from dataFrame
df.drop(CrudeRate, inplace=True)

# Display dataframe
df
# Out:
#         State  Year    Drug/Alcohol Induced  \
# 0     Alabama  1999     Drug-induced causes
# 1     Alabama  1999     Drug-induced causes
# 3     Alabama  1999     Drug-induced causes
# 4     Alabama  1999  Alcohol-induced causes
# 6     Alabama  2000     Drug-induced causes
# 7     Alabama  2000     Drug-induced causes
# 8     Alabama  2000     Drug-induced causes
# 9     Alabama  2000     Drug-induced causes
# 10    Alabama  2000  Alcohol-induced causes
# 12    Alabama  2001     Drug-induced causes
# 13    Alabama  2001     Drug-induced causes
# 15    Alabama  2001     Drug-induced causes
# 16    Alabama  2001  Alcohol-induced causes
# 18    Alabama  2002     Drug-induced causes
# 19    Alabama  2002     Drug-induced causes
# 21    Alabama  2002     Drug-induced causes
# 22    Alabama  2002  Alcohol-induced causes
# 24    Alabama  2003     Drug-induced causes
# 25    Alabama  2003     Drug-induced causes
# 26    Alabama  2003     Drug-induced causes
# ...

# %%
# Save dataframe to csv file
df.to_csv(r'DrugDeaths_ByState.csv')
